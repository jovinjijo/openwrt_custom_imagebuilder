# %%
# !apt-get install build-essential libncurses5-dev libncursesw5-dev zlib1g-dev gawk git gettext libssl-dev xsltproc wget unzip python file time
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# gawk is already the newest version (1:4.1.4+dfsg-1build1).
# python is already the newest version (2.7.15~rc1-1).
# time is already the newest version (1.7-25.1build1).
# unzip is already the newest version (6.0-21ubuntu1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# file is already the newest version (1:5.32-2ubuntu0.4).
# gettext is already the newest version (0.19.8.1-6ubuntu0.3).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libncurses5-dev is already the newest version (6.1-1ubuntu1.18.04).
# libncursesw5-dev is already the newest version (6.1-1ubuntu1.18.04).
# libssl-dev is already the newest version (1.1.1-1ubuntu2.1~18.04.6).
# wget is already the newest version (1.19.4-1ubuntu2.2).
# xsltproc is already the newest version (1.1.29-5ubuntu0.2).
# ...

# %%
# !wget https://mirrors.a-m-v.pl/downloads.openwrt.org/releases/17.01.7/targets/ar71xx/generic/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64.tar.xz
# Out:
# --2020-10-07 18:40:56--  https://mirrors.a-m-v.pl/downloads.openwrt.org/releases/17.01.7/targets/ar71xx/generic/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64.tar.xz
# Resolving mirrors.a-m-v.pl (mirrors.a-m-v.pl)... 104.28.11.106, 104.28.10.106, 172.67.134.162, ...
# Connecting to mirrors.a-m-v.pl (mirrors.a-m-v.pl)|104.28.11.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226033764 (216M) [application/octet-stream]
# Saving to: ‘lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64.tar.xz’
#
# lede-imagebuilder-1 100%[===================>] 215.56M   167MB/s    in 1.3s
#
# 2020-10-07 18:40:57 (167 MB/s) - ‘lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64.tar.xz’ saved [226033764/226033764]

# %%
# !tar xvf lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64.tar.xz
# Out:
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/.targetinfo
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-video-gspca-mars_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-crypto-hw-geode_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-usb-net-kaweth_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-usb-net-cdc-ncm_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-pktgen_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-zram_4.4.182-1_mips_24kc.ipk
# lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/packages/kmod-via-velocity_4.4.182-1_mips_24kc.ipk
# ...

# %%
# %cd lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64
# !ls
# Out:
# /content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64
# build_dir  Makefile  repositories.conf	scripts      target
# include    packages  rules.mk		staging_dir

# %%
# %env TARGET_SQUASHFS_BLOCK_SIZE=512
# %env CONFIG_PACKAGE_MAC80211_MESH=n
# %env CONFIG_PACKAGE_MAC80211_DEBUGFS=n

# !make image PROFILE=tl-wr841-v9 PACKAGES="luci-app-mwan3 mwan3 luci-base luci-app-firewall luci-mod-admin-full luci-theme-bootstrap uhttpd uhttpd-mod-ubus libiwinfo-lua -opkg -ip6tables -odhcp6c -kmod-ipv6 -kmod-ip6tables -odhcpd-ipv6only" V=s
# Out:
# env: TARGET_SQUASHFS_BLOCK_SIZE=512
# env: CONFIG_PACKAGE_MAC80211_MESH=n
# env: CONFIG_PACKAGE_MAC80211_DEBUGFS=n
# Building images for ar71xx - TP-LINK TL-WR841N/ND v9
# Packages: luci-app-mwan3 mwan3 luci-base luci-app-firewall luci-mod-admin-full luci-theme-bootstrap uhttpd uhttpd-mod-ubus libiwinfo-lua base-files busybox dnsmasq dropbear firewall fstools iptables kernel kmod-ath9k kmod-gpio-button-hotplug libc libgcc logd mtd netifd odhcpd ppp ppp-mod-pppoe swconfig uboot-envtools uci uclient-fetch wpad-mini
#
# ...
# Updated list of available packages in /content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/build_dir/target-mips_24kc_musl-1.1.16/root-ar71xx/../../../../../../content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/dl/reboot_core
# ...

# %%
from google.colab import files
# !pwd
# !ls /content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/build_dir/target-mips_24kc_musl-1.1.16/linux-ar71xx_generic/tmp/
files.download('/content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/build_dir/target-mips_24kc_musl-1.1.16/linux-ar71xx_generic/tmp/lede-17.01.7-ar71xx-generic-tl-wr841-v9-squashfs-sysupgrade.bin')
# Out:
# /content/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64/lede-imagebuilder-17.01.7-ar71xx-generic.Linux-x86_64
# lede-17.01.7-ar71xx-generic-tl-wr841-v9-squashfs-factory.bin
# lede-17.01.7-ar71xx-generic-tl-wr841-v9-squashfs-sysupgrade.bin
